# %%
import PseudoNetCDF as pnc
import cartopy.crs as ccrs
from cartopy import config
import matplotlib.pyplot as plt


inpath = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170126_R20.ict'

infile = pnc.pncopen(inpath, format = 'ffi1001')
print(infile)



# Optionally, add dimension slicing
# infile = infile.sliceDimensions(<layer-dim-name> = 0)
# infile = infile.applyAlongDimenions(<time-dim-name> = 'mean')
#patches = infile.plot("G_ALT", plottype = 'longitude-latitude')
#patches.axes.figure.savefig('/Users/mshogrin/Downloads/')
# infile.save(outpath)
# Out:
# PseudoNetCDF.icarttfiles.ffi1001.ffi1001 unknown {
# dimensions:
#         POINTS = 309 ;
#
# variables:
#         double UTC_Start(POINTS);
#                 UTC_Start:units = "s" ;
#                 UTC_Start:standard_name = "UTC_Start" ;
#                 UTC_Start:missing_value = -99999 ;
#                 UTC_Start:fill_value = -99999.0 ;
#                 UTC_Start:scale = 1 ;
#                 UTC_Start:llod_flag = -8888 ;
#                 UTC_Start:llod_value = "N/A" ;
#                 UTC_Start:ulod_flag = -7777 ;
#                 UTC_Start:ulod_value = "N/A" ;
#         double UTC_Stop_TOGA(POINTS);
#                 UTC_Stop_TOGA:units = "s" ;
#                 UTC_Stop_TOGA:standard_name = "UTC_Stop_TOGA" ;
#                 UTC_Stop_TOGA:missing_value = -99999 ;
#                 UTC_Stop_TOGA:fill_value = -99999.0 ;
#                 UTC_Stop_TOGA:scale = 1 ;
#                 UTC_Stop_TOGA:llod_flag = -8888 ;
#                 UTC_Stop_TOGA:llod_value = "N/A" ;
#                 UTC_Stop_TOGA:ulod_flag = -7777 ;
#                 UTC_Stop_TOGA:ulod_value = "N/A" ;
#         double CFC11_TOGA(POINTS);
#                 CFC11_TOGA:units = "s" ;
#                 CFC11_TOGA:standard_name = "CFC11_TOGA" ;
#                 CFC11_TOGA:missing_value = -99999 ;
#                 CFC11_TOGA:fill_value = -99999.0 ;
#                 CFC11_TOGA:scale = 1 ;
#                 CFC11_TOGA:llod_flag = -8888 ;
#                 CFC11_TOGA:llod_value = "N/A" ;
#                 CFC11_TOGA:ulod_flag = -7777 ;
#                 CFC11_TOGA:ulod_value = "N/A" ;
#         double UTC_Mean_1s(POINTS);
#                 UTC_Mean_1s:units = "s" ;
#                 UTC_Mean_1s:standard_name = "UTC_Mean_1s" ;
#                 UTC_Mean_1s:missing_value = -99999 ;
#                 UTC_Mean_1s:fill_value = -99999.0 ;
#                 UTC_Mean_1s:scale = 1 ;
#                 UTC_Mean_1s:llod_flag = -8888 ;
#                 UTC_Mean_1s:llod_value = "N/A" ;
#                 UTC_Mean_1s:ulod_flag = -7777 ;
#                 UTC_Mean_1s:ulod_value = "N/A" ;
#         double P(POINTS);
#                 P:units = "hPa" ;
#                 P:standard_name = "P" ;
#                 P:missing_value = -99999 ;
#                 P:fill_value = -99999.0 ;
#                 P:scale = 1 ;
#                 P:llod_flag = -8888 ;
#                 P:llod_value = "N/A" ;
#                 P:ulod_flag = -7777 ;
#                 P:ulod_value = "N/A" ;
#         double T(POINTS);
#                 T:units = "K" ;
#                 T:standard_name = "T" ;
#                 T:missing_value = -99999 ;
#                 T:fill_value = -99999.0 ;
#                 T:scale = 1 ;
#                 T:llod_flag = -8888 ;
#                 T:llod_value = "N/A" ;
#                 T:ulod_flag = -7777 ;
#                 T:ulod_value = "N/A" ;
#         double TAS(POINTS);
#                 TAS:units = "m/s" ;
#                 TAS:standard_name = "TAS" ;
#                 TAS:missing_value = -99999 ;
#                 TAS:fill_value = -99999.0 ;
#                 TAS:scale = 1 ;
#                 TAS:llod_flag = -8888 ;
#                 TAS:llod_value = "N/A" ;
#                 TAS:ulod_flag = -7777 ;
#                 TAS:ulod_value = "N/A" ;
#         double U(POINTS);
#                 U:units = "m/s" ;
#                 U:standard_name = "U" ;
#                 U:missing_value = -99999 ;
#                 U:fill_value = -99999.0 ;
#                 U:scale = 1 ;
#                 U:llod_flag = -8888 ;
#                 U:llod_value = "N/A" ;
#                 U:ulod_flag = -7777 ;
#                 U:ulod_value = "N/A" ;
#         double V(POINTS);
#                 V:units = "m/s" ;
#                 V:standard_name = "V" ;
#                 V:missing_value = -99999 ;
#                 V:fill_value = -99999.0 ;
#                 V:scale = 1 ;
#                 V:llod_flag = -8888 ;
#                 V:llod_value = "N/A" ;
#                 V:ulod_flag = -7777 ;
#                 V:ulod_value = "N/A" ;
#         double W(POINTS);
#                 W:units = "m/s" ;
#                 W:standard_name = "W" ;
#                 W:missing_value = -99999 ;
#                 W:fill_value = -99999.0 ;
#                 W:scale = 1 ;
#                 W:llod_flag = -8888 ;
#                 W:llod_value = "N/A" ;
#                 W:ulod_flag = -7777 ;
#                 W:ulod_value = "N/A" ;
#         double TEDR(POINTS);
#                 TEDR:units = "kW/kg" ;
#                 TEDR:standard_name = "TEDR" ;
#                 TEDR:missing_value = -99999 ;
#                 TEDR:fill_value = -99999.0 ;
#                 TEDR:scale = 1 ;
#                 TEDR:llod_flag = -8888 ;
#                 TEDR:llod_value = "N/A" ;
#                 TEDR:ulod_flag = -7777 ;
#                 TEDR:ulod_value = "N/A" ;
#         double REYN(POINTS);
#                 REYN:units = "/m" ;
#                 REYN:standard_name = "REYN" ;
#                 REYN:missing_value = -99999 ;
#                 REYN:fill_value = -99999.0 ;
#                 REYN:scale = 1 ;
#                 REYN:llod_flag = -8888 ;
#                 REYN:llod_value = "N/A" ;
#                 REYN:ulod_flag = -7777 ;
#                 REYN:ulod_value = "N/A" ;
#         double G_LAT(POINTS);
#                 G_LAT:units = "deg +N" ;
#                 G_LAT:standard_name = "G_LAT" ;
#                 G_LAT:missing_value = -99999 ;
#                 G_LAT:fill_value = -99999.0 ;
#                 G_LAT:scale = 1 ;
#                 G_LAT:llod_flag = -8888 ;
#                 G_LAT:llod_value = "N/A" ;
#                 G_LAT:ulod_flag = -7777 ;
#                 G_LAT:ulod_value = "N/A" ;
#         double G_LONG(POINTS);
#                 G_LONG:units = "deg +E" ;
#                 G_LONG:standard_name = "G_LONG" ;
#                 G_LONG:missing_value = -99999 ;
#                 G_LONG:fill_value = -99999.0 ;
#                 G_LONG:scale = 1 ;
#                 G_LONG:llod_flag = -8888 ;
#                 G_LONG:llod_value = "N/A" ;
#                 G_LONG:ulod_flag = -7777 ;
#                 G_LONG:ulod_value = "N/A" ;
#         double G_ALT(POINTS);
#                 G_ALT:units = "m" ;
#                 G_ALT:standard_name = "G_ALT" ;
#                 G_ALT:missing_value = -99999 ;
#                 G_ALT:fill_value = -99999.0 ;
#                 G_ALT:scale = 1 ;
#                 G_ALT:llod_flag = -8888 ;
#                 G_ALT:llod_value = "N/A" ;
#                 G_ALT:ulod_flag = -7777 ;
#                 G_ALT:ulod_value = "N/A" ;
#         double POT(POINTS);
#                 POT:units = "K" ;
#                 POT:standard_name = "POT" ;
#                 POT:missing_value = -99999 ;
#                 POT:fill_value = -99999.0 ;
#                 POT:scale = 1 ;
#                 POT:llod_flag = -8888 ;
#                 POT:llod_value = "N/A" ;
#                 POT:ulod_flag = -7777 ;
#                 POT:ulod_value = "N/A" ;
#         double ROLL(POINTS);
#                 ROLL:units = "deg" ;
#                 ROLL:standard_name = "ROLL" ;
#                 ROLL:missing_value = -99999 ;
#                 ROLL:fill_value = -99999.0 ;
#                 ROLL:scale = 1 ;
#                 ROLL:llod_flag = -8888 ;
#                 ROLL:llod_value = "N/A" ;
#                 ROLL:ulod_flag = -7777 ;
#                 ROLL:ulod_value = "N/A" ;
#         double HDG(POINTS);
#                 HDG:units = "deg" ;
#                 HDG:standard_name = "HDG" ;
#                 HDG:missing_value = -99999 ;
#                 HDG:fill_value = -99999.0 ;
#                 HDG:scale = 1 ;
#                 HDG:llod_flag = -8888 ;
#                 HDG:llod_value = "N/A" ;
#                 HDG:ulod_flag = -7777 ;
#                 HDG:ulod_value = "N/A" ;
#         double PITCH(POINTS);
#                 PITCH:units = "deg" ;
#                 PITCH:standard_name = "PITCH" ;
#                 PITCH:missing_value = -99999 ;
#                 PITCH:fill_value = -99999.0 ;
#                 PITCH:scale = 1 ;
#                 PITCH:llod_flag = -8888 ;
#                 PITCH:llod_value = "N/A" ;
#                 PITCH:ulod_flag = -7777 ;
#                 PITCH:ulod_value = "N/A" ;
#         double YAW(POINTS);
#                 YAW:units = "deg" ;
#                 YAW:standard_name = "YAW" ;
#                 YAW:missing_value = -99999 ;
#                 YAW:fill_value = -99999.0 ;
#                 YAW:scale = 1 ;
#                 YAW:llod_flag = -8888 ;
#                 YAW:llod_value = "N/A" ;
#                 YAW:ulod_flag = -7777 ;
#                 YAW:ulod_value = "N/A" ;
#         double AOA(POINTS);
#                 AOA:units = "deg" ;
#                 AOA:standard_name = "AOA" ;
#                 AOA:missing_value = -99999 ;
#                 AOA:fill_value = -99999.0 ;
#                 AOA:scale = 1 ;
#                 AOA:llod_flag = -8888 ;
#                 AOA:llod_value = "N/A" ;
#                 AOA:ulod_flag = -7777 ;
#                 AOA:ulod_value = "N/A" ;
#         double Stoptime_AMS(POINTS);
#                 Stoptime_AMS:units = "seconds_past_midnight" ;
#                 Stoptime_AMS:standard_name = "Stoptime_AMS" ;
#                 Stoptime_AMS:missing_value = -99999 ;
#                 Stoptime_AMS:fill_value = -99999.0 ;
#                 Stoptime_AMS:scale = 1 ;
#                 Stoptime_AMS:llod_flag = -8888 ;
#                 Stoptime_AMS:llod_value = "N/A" ;
#                 Stoptime_AMS:ulod_flag = -7777 ;
#                 Stoptime_AMS:ulod_value = "N/A" ;
#         double MidPointTime_AMS(POINTS);
#                 MidPointTime_AMS:units = "seconds_past_midnight" ;
#                 MidPointTime_AMS:standard_name = "MidPointTime_AMS" ;
#                 MidPointTime_AMS:missing_value = -99999 ;
#                 MidPointTime_AMS:fill_value = -99999.0 ;
#                 MidPointTime_AMS:scale = 1 ;
#                 MidPointTime_AMS:llod_flag = -8888 ;
#                 MidPointTime_AMS:llod_value = "N/A" ;
#                 MidPointTime_AMS:ulod_flag = -7777 ;
#                 MidPointTime_AMS:ulod_value = "N/A" ;
#         double LAT_AMS(POINTS);
#                 LAT_AMS:units = "deg" ;
#                 LAT_AMS:standard_name = "LAT_AMS" ;
#                 LAT_AMS:missing_value = -99999 ;
#                 LAT_AMS:fill_value = -99999.0 ;
#                 LAT_AMS:scale = 1 ;
#                 LAT_AMS:llod_flag = -8888 ;
#                 LAT_AMS:llod_value = "N/A" ;
#                 LAT_AMS:ulod_flag = -7777 ;
#                 LAT_AMS:ulod_value = "N/A" ;
#         double LON_AMS(POINTS);
#                 LON_AMS:units = "deg" ;
#                 LON_AMS:standard_name = "LON_AMS" ;
#                 LON_AMS:missing_value = -99999 ;
#                 LON_AMS:fill_value = -99999.0 ;
#                 LON_AMS:scale = 1 ;
#                 LON_AMS:llod_flag = -8888 ;
#                 LON_AMS:llod_value = "N/A" ;
#                 LON_AMS:ulod_flag = -7777 ;
#                 LON_AMS:ulod_value = "N/A" ;
#         double ALT_AMS(POINTS);
#                 ALT_AMS:units = "m" ;
#                 ALT_AMS:standard_name = "ALT_AMS" ;
#                 ALT_AMS:missing_value = -99999 ;
#                 ALT_AMS:fill_value = -99999.0 ;
#                 ALT_AMS:scale = 1 ;
#                 ALT_AMS:llod_flag = -8888 ;
#                 ALT_AMS:llod_value = "N/A" ;
#                 ALT_AMS:ulod_flag = -7777 ;
#                 ALT_AMS:ulod_value = "N/A" ;
#         double OA_PM1_AMS(POINTS);
#                 OA_PM1_AMS:units = "ug sm-3" ;
#                 OA_PM1_AMS:standard_name = "OA_PM1_AMS" ;
#                 OA_PM1_AMS:missing_value = -99999 ;
#                 OA_PM1_AMS:fill_value = -99999.0 ;
#                 OA_PM1_AMS:scale = 1 ;
#                 OA_PM1_AMS:llod_flag = -8888 ;
#                 OA_PM1_AMS:llod_value = "N/A" ;
#                 OA_PM1_AMS:ulod_flag = -7777 ;
#                 OA_PM1_AMS:ulod_value = "N/A" ;
#         double OA_prec_PM1_AMS(POINTS);
#                 OA_prec_PM1_AMS:units = "ug sm-3" ;
#                 OA_prec_PM1_AMS:standard_name = "OA_prec_PM1_AMS" ;
#                 OA_prec_PM1_AMS:missing_value = -99999 ;
#                 OA_prec_PM1_AMS:fill_value = -99999.0 ;
#                 OA_prec_PM1_AMS:scale = 1 ;
#                 OA_prec_PM1_AMS:llod_flag = -8888 ;
#                 OA_prec_PM1_AMS:llod_value = "N/A" ;
#                 OA_prec_PM1_AMS:ulod_flag = -7777 ;
#                 OA_prec_PM1_AMS:ulod_value = "N/A" ;
#         double OA_DL_PM1_AMS(POINTS);
#                 OA_DL_PM1_AMS:units = "ug sm-3" ;
#                 OA_DL_PM1_AMS:standard_name = "OA_DL_PM1_AMS" ;
#                 OA_DL_PM1_AMS:missing_value = -99999 ;
#                 OA_DL_PM1_AMS:fill_value = -99999.0 ;
#                 OA_DL_PM1_AMS:scale = 1 ;
#                 OA_DL_PM1_AMS:llod_flag = -8888 ;
#                 OA_DL_PM1_AMS:llod_value = "N/A" ;
#                 OA_DL_PM1_AMS:ulod_flag = -7777 ;
#                 OA_DL_PM1_AMS:ulod_value = "N/A" ;
#         double Sulfate_PM1_AMS(POINTS);
#                 Sulfate_PM1_AMS:units = "ug sm-3" ;
#                 Sulfate_PM1_AMS:standard_name = "Sulfate_PM1_AMS" ;
#                 Sulfate_PM1_AMS:missing_value = -99999 ;
#                 Sulfate_PM1_AMS:fill_value = -99999.0 ;
#                 Sulfate_PM1_AMS:scale = 1 ;
#                 Sulfate_PM1_AMS:llod_flag = -8888 ;
#                 Sulfate_PM1_AMS:llod_value = "N/A" ;
#                 Sulfate_PM1_AMS:ulod_flag = -7777 ;
#                 Sulfate_PM1_AMS:ulod_value = "N/A" ;
#         double Sulfate_prec_PM1_AMS(POINTS);
#                 Sulfate_prec_PM1_AMS:units = "ug sm-3" ;
#                 Sulfate_prec_PM1_AMS:standard_name = "Sulfate_prec_PM1_AMS" ;
#                 Sulfate_prec_PM1_AMS:missing_value = -99999 ;
#                 Sulfate_prec_PM1_AMS:fill_value = -99999.0 ;
#                 Sulfate_prec_PM1_AMS:scale = 1 ;
#                 Sulfate_prec_PM1_AMS:llod_flag = -8888 ;
#                 Sulfate_prec_PM1_AMS:llod_value = "N/A" ;
#                 Sulfate_prec_PM1_AMS:ulod_flag = -7777 ;
#                 Sulfate_prec_PM1_AMS:ulod_value = "N/A" ;
#         double Sulfate_DL_PM1_AMS(POINTS);
#                 Sulfate_DL_PM1_AMS:units = "ug sm-3" ;
#                 Sulfate_DL_PM1_AMS:standard_name = "Sulfate_DL_PM1_AMS" ;
#                 Sulfate_DL_PM1_AMS:missing_value = -99999 ;
#                 Sulfate_DL_PM1_AMS:fill_value = -99999.0 ;
#                 Sulfate_DL_PM1_AMS:scale = 1 ;
#                 Sulfate_DL_PM1_AMS:llod_flag = -8888 ;
#                 Sulfate_DL_PM1_AMS:llod_value = "N/A" ;
#                 Sulfate_DL_PM1_AMS:ulod_flag = -7777 ;
#                 Sulfate_DL_PM1_AMS:ulod_value = "N/A" ;
#         double Nitrate_PM1_AMS(POINTS);
#                 Nitrate_PM1_AMS:units = "ug sm-3" ;
#                 Nitrate_PM1_AMS:standard_name = "Nitrate_PM1_AMS" ;
#                 Nitrate_PM1_AMS:missing_value = -99999 ;
#                 Nitrate_PM1_AMS:fill_value = -99999.0 ;
#                 Nitrate_PM1_AMS:scale = 1 ;
#                 Nitrate_PM1_AMS:llod_flag = -8888 ;
#                 Nitrate_PM1_AMS:llod_value = "N/A" ;
#                 Nitrate_PM1_AMS:ulod_flag = -7777 ;
#                 Nitrate_PM1_AMS:ulod_value = "N/A" ;
#         double Nitrate_prec_PM1_AMS(POINTS);
#                 Nitrate_prec_PM1_AMS:units = "ug sm-3" ;
#                 Nitrate_prec_PM1_AMS:standard_name = "Nitrate_prec_PM1_AMS" ;
#                 Nitrate_prec_PM1_AMS:missing_value = -99999 ;
#                 Nitrate_prec_PM1_AMS:fill_value = -99999.0 ;
#                 Nitrate_prec_PM1_AMS:scale = 1 ;
#                 Nitrate_prec_PM1_AMS:llod_flag = -8888 ;
#                 Nitrate_prec_PM1_AMS:llod_value = "N/A" ;
#                 Nitrate_prec_PM1_AMS:ulod_flag = -7777 ;
#                 Nitrate_prec_PM1_AMS:ulod_value = "N/A" ;
#         double Nitrate_DL_PM1_AMS(POINTS);
#                 Nitrate_DL_PM1_AMS:units = "ug sm-3" ;
#                 Nitrate_DL_PM1_AMS:standard_name = "Nitrate_DL_PM1_AMS" ;
#                 Nitrate_DL_PM1_AMS:missing_value = -99999 ;
#                 Nitrate_DL_PM1_AMS:fill_value = -99999.0 ;
#                 Nitrate_DL_PM1_AMS:scale = 1 ;
#                 Nitrate_DL_PM1_AMS:llod_flag = -8888 ;
#                 Nitrate_DL_PM1_AMS:llod_value = "N/A" ;
#                 Nitrate_DL_PM1_AMS:ulod_flag = -7777 ;
#                 Nitrate_DL_PM1_AMS:ulod_value = "N/A" ;
#         double Ammonium_PM1_AMS(POINTS);
#                 Ammonium_PM1_AMS:units = "ug sm-3" ;
#                 Ammonium_PM1_AMS:standard_name = "Ammonium_PM1_AMS" ;
#                 Ammonium_PM1_AMS:missing_value = -99999 ;
#                 Ammonium_PM1_AMS:fill_value = -99999.0 ;
#                 Ammonium_PM1_AMS:scale = 1 ;
#                 Ammonium_PM1_AMS:llod_flag = -8888 ;
#                 Ammonium_PM1_AMS:llod_value = "N/A" ;
#                 Ammonium_PM1_AMS:ulod_flag = -7777 ;
#                 Ammonium_PM1_AMS:ulod_value = "N/A" ;
#         double Ammonium_prec_PM1_AMS(POINTS);
#                 Ammonium_prec_PM1_AMS:units = "ug sm-3" ;
#                 Ammonium_prec_PM1_AMS:standard_name = "Ammonium_prec_PM1_AMS" ;
#                 Ammonium_prec_PM1_AMS:missing_value = -99999 ;
#                 Ammonium_prec_PM1_AMS:fill_value = -99999.0 ;
#                 Ammonium_prec_PM1_AMS:scale = 1 ;
#                 Ammonium_prec_PM1_AMS:llod_flag = -8888 ;
#                 Ammonium_prec_PM1_AMS:llod_value = "N/A" ;
#                 Ammonium_prec_PM1_AMS:ulod_flag = -7777 ;
#                 Ammonium_prec_PM1_AMS:ulod_value = "N/A" ;
#         double Ammonium_DL_PM1_AMS(POINTS);
#                 Ammonium_DL_PM1_AMS:units = "ug sm-3" ;
#                 Ammonium_DL_PM1_AMS:standard_name = "Ammonium_DL_PM1_AMS" ;
#                 Ammonium_DL_PM1_AMS:missing_value = -99999 ;
#                 Ammonium_DL_PM1_AMS:fill_value = -99999.0 ;
#                 Ammonium_DL_PM1_AMS:scale = 1 ;
#                 Ammonium_DL_PM1_AMS:llod_flag = -8888 ;
#                 Ammonium_DL_PM1_AMS:llod_value = "N/A" ;
#                 Ammonium_DL_PM1_AMS:ulod_flag = -7777 ;
#                 Ammonium_DL_PM1_AMS:ulod_value = "N/A" ;
#         double Chloride_PM1_AMS(POINTS);
#                 Chloride_PM1_AMS:units = "ug sm-3" ;
#                 Chloride_PM1_AMS:standard_name = "Chloride_PM1_AMS" ;
#                 Chloride_PM1_AMS:missing_value = -99999 ;
#                 Chloride_PM1_AMS:fill_value = -99999.0 ;
#                 Chloride_PM1_AMS:scale = 1 ;
#                 Chloride_PM1_AMS:llod_flag = -8888 ;
#                 Chloride_PM1_AMS:llod_value = "N/A" ;
#                 Chloride_PM1_AMS:ulod_flag = -7777 ;
#                 Chloride_PM1_AMS:ulod_value = "N/A" ;
#         double Chloride_prec_PM1_AMS(POINTS);
#                 Chloride_prec_PM1_AMS:units = "ug sm-3" ;
#                 Chloride_prec_PM1_AMS:standard_name = "Chloride_prec_PM1_AMS" ;
#                 Chloride_prec_PM1_AMS:missing_value = -99999 ;
#                 Chloride_prec_PM1_AMS:fill_value = -99999.0 ;
#                 Chloride_prec_PM1_AMS:scale = 1 ;
#                 Chloride_prec_PM1_AMS:llod_flag = -8888 ;
#                 Chloride_prec_PM1_AMS:llod_value = "N/A" ;
#                 Chloride_prec_PM1_AMS:ulod_flag = -7777 ;
#                 Chloride_prec_PM1_AMS:ulod_value = "N/A" ;
#         double Chloride_DL_PM1_AMS(POINTS);
#                 Chloride_DL_PM1_AMS:units = "ug sm-3" ;
#                 Chloride_DL_PM1_AMS:standard_name = "Chloride_DL_PM1_AMS" ;
#                 Chloride_DL_PM1_AMS:missing_value = -99999 ;
#                 Chloride_DL_PM1_AMS:fill_value = -99999.0 ;
#                 Chloride_DL_PM1_AMS:scale = 1 ;
#                 Chloride_DL_PM1_AMS:llod_flag = -8888 ;
#                 Chloride_DL_PM1_AMS:llod_value = "N/A" ;
#                 Chloride_DL_PM1_AMS:ulod_flag = -7777 ;
#                 Chloride_DL_PM1_AMS:ulod_value = "N/A" ;
#         double StdtoVol_AMS(POINTS);
#                 StdtoVol_AMS:units = "m3 sm-3" ;
#                 StdtoVol_AMS:standard_name = "StdtoVol_AMS" ;
#                 StdtoVol_AMS:missing_value = -99999 ;
#                 StdtoVol_AMS:fill_value = -99999.0 ;
#                 StdtoVol_AMS:scale = 1 ;
#                 StdtoVol_AMS:llod_flag = -8888 ;
#                 StdtoVol_AMS:llod_value = "N/A" ;
#                 StdtoVol_AMS:ulod_flag = -7777 ;
#                 StdtoVol_AMS:ulod_value = "N/A" ;
#         double CloudFlag_AMS(POINTS);
#                 CloudFlag_AMS:units = "unitless" ;
#                 CloudFlag_AMS:standard_name = "CloudFlag_AMS" ;
#                 CloudFlag_AMS:missing_value = -99999 ;
#                 CloudFlag_AMS:fill_value = -99999.0 ;
#                 CloudFlag_AMS:scale = 1 ;
#                 CloudFlag_AMS:llod_flag = -8888 ;
#                 CloudFlag_AMS:llod_value = "N/A" ;
#                 CloudFlag_AMS:ulod_flag = -7777 ;
#                 CloudFlag_AMS:ulod_value = "N/A" ;
#         double AmmBalance_PM1_AMS(POINTS);
#                 AmmBalance_PM1_AMS:units = "unitless" ;
#                 AmmBalance_PM1_AMS:standard_name = "AmmBalance_PM1_AMS" ;
#                 AmmBalance_PM1_AMS:missing_value = -99999 ;
#                 AmmBalance_PM1_AMS:fill_value = -99999.0 ;
#                 AmmBalance_PM1_AMS:scale = 1 ;
#                 AmmBalance_PM1_AMS:llod_flag = -8888 ;
#                 AmmBalance_PM1_AMS:llod_value = "N/A" ;
#                 AmmBalance_PM1_AMS:ulod_flag = -7777 ;
#                 AmmBalance_PM1_AMS:ulod_value = "N/A" ;
#         double Density_PM1_AMS(POINTS);
#                 Density_PM1_AMS:units = "g cm-3" ;
#                 Density_PM1_AMS:standard_name = "Density_PM1_AMS" ;
#                 Density_PM1_AMS:missing_value = -99999 ;
#                 Density_PM1_AMS:fill_value = -99999.0 ;
#                 Density_PM1_AMS:scale = 1 ;
#                 Density_PM1_AMS:llod_flag = -8888 ;
#                 Density_PM1_AMS:llod_value = "N/A" ;
#                 Density_PM1_AMS:ulod_flag = -7777 ;
#                 Density_PM1_AMS:ulod_value = "N/A" ;
#         double OADensity_PM1_AMS(POINTS);
#                 OADensity_PM1_AMS:units = "g cm-3" ;
#                 OADensity_PM1_AMS:standard_name = "OADensity_PM1_AMS" ;
#                 OADensity_PM1_AMS:missing_value = -99999 ;
#                 OADensity_PM1_AMS:fill_value = -99999.0 ;
#                 OADensity_PM1_AMS:scale = 1 ;
#                 OADensity_PM1_AMS:llod_flag = -8888 ;
#                 OADensity_PM1_AMS:llod_value = "N/A" ;
#                 OADensity_PM1_AMS:ulod_flag = -7777 ;
#                 OADensity_PM1_AMS:ulod_value = "N/A" ;
#         double OtoC_Ratio_PM1_AMS(POINTS);
#                 OtoC_Ratio_PM1_AMS:units = "unitless" ;
#                 OtoC_Ratio_PM1_AMS:standard_name = "OtoC_Ratio_PM1_AMS" ;
#                 OtoC_Ratio_PM1_AMS:missing_value = -99999 ;
#                 OtoC_Ratio_PM1_AMS:fill_value = -99999.0 ;
#                 OtoC_Ratio_PM1_AMS:scale = 1 ;
#                 OtoC_Ratio_PM1_AMS:llod_flag = -8888 ;
#                 OtoC_Ratio_PM1_AMS:llod_value = "N/A" ;
#                 OtoC_Ratio_PM1_AMS:ulod_flag = -7777 ;
#                 OtoC_Ratio_PM1_AMS:ulod_value = "N/A" ;
#         double HtoC_Ratio_PM1_AMS(POINTS);
#                 HtoC_Ratio_PM1_AMS:units = "unitless" ;
#                 HtoC_Ratio_PM1_AMS:standard_name = "HtoC_Ratio_PM1_AMS" ;
#                 HtoC_Ratio_PM1_AMS:missing_value = -99999 ;
#                 HtoC_Ratio_PM1_AMS:fill_value = -99999.0 ;
#                 HtoC_Ratio_PM1_AMS:scale = 1 ;
#                 HtoC_Ratio_PM1_AMS:llod_flag = -8888 ;
#                 HtoC_Ratio_PM1_AMS:llod_value = "N/A" ;
#                 HtoC_Ratio_PM1_AMS:ulod_flag = -7777 ;
#                 HtoC_Ratio_PM1_AMS:ulod_value = "N/A" ;
#         double OAtoOC_PM1_AMS(POINTS);
#                 OAtoOC_PM1_AMS:units = "unitless" ;
#                 OAtoOC_PM1_AMS:standard_name = "OAtoOC_PM1_AMS" ;
#                 OAtoOC_PM1_AMS:missing_value = -99999 ;
#                 OAtoOC_PM1_AMS:fill_value = -99999.0 ;
#                 OAtoOC_PM1_AMS:scale = 1 ;
#                 OAtoOC_PM1_AMS:llod_flag = -8888 ;
#                 OAtoOC_PM1_AMS:llod_value = "N/A" ;
#                 OAtoOC_PM1_AMS:ulod_flag = -7777 ;
#                 OAtoOC_PM1_AMS:ulod_value = "N/A" ;
#         double OSc_PM1_AMS(POINTS);
#                 OSc_PM1_AMS:units = "unitless" ;
#                 OSc_PM1_AMS:standard_name = "OSc_PM1_AMS" ;
#                 OSc_PM1_AMS:missing_value = -99999 ;
#                 OSc_PM1_AMS:fill_value = -99999.0 ;
#                 OSc_PM1_AMS:scale = 1 ;
#                 OSc_PM1_AMS:llod_flag = -8888 ;
#                 OSc_PM1_AMS:llod_value = "N/A" ;
#                 OSc_PM1_AMS:ulod_flag = -7777 ;
#                 OSc_PM1_AMS:ulod_value = "N/A" ;
#         double f43_PM1_AMS(POINTS);
#                 f43_PM1_AMS:units = "unitless" ;
#                 f43_PM1_AMS:standard_name = "f43_PM1_AMS" ;
#                 f43_PM1_AMS:missing_value = -99999 ;
#                 f43_PM1_AMS:fill_value = -99999.0 ;
#                 f43_PM1_AMS:scale = 1 ;
#                 f43_PM1_AMS:llod_flag = -8888 ;
#                 f43_PM1_AMS:llod_value = "N/A" ;
#                 f43_PM1_AMS:ulod_flag = -7777 ;
#                 f43_PM1_AMS:ulod_value = "N/A" ;
#         double f44_PM1_AMS(POINTS);
#                 f44_PM1_AMS:units = "unitless" ;
#                 f44_PM1_AMS:standard_name = "f44_PM1_AMS" ;
#                 f44_PM1_AMS:missing_value = -99999 ;
#                 f44_PM1_AMS:fill_value = -99999.0 ;
#                 f44_PM1_AMS:scale = 1 ;
#                 f44_PM1_AMS:llod_flag = -8888 ;
#                 f44_PM1_AMS:llod_value = "N/A" ;
#                 f44_PM1_AMS:ulod_flag = -7777 ;
#                 f44_PM1_AMS:ulod_value = "N/A" ;
#         double f57_PM1_AMS(POINTS);
#                 f57_PM1_AMS:units = "unitless" ;
#                 f57_PM1_AMS:standard_name = "f57_PM1_AMS" ;
#                 f57_PM1_AMS:missing_value = -99999 ;
#                 f57_PM1_AMS:fill_value = -99999.0 ;
#                 f57_PM1_AMS:scale = 1 ;
#                 f57_PM1_AMS:llod_flag = -8888 ;
#                 f57_PM1_AMS:llod_value = "N/A" ;
#                 f57_PM1_AMS:ulod_flag = -7777 ;
#                 f57_PM1_AMS:ulod_value = "N/A" ;
#         double f60_PM1_AMS(POINTS);
#                 f60_PM1_AMS:units = "unitless" ;
#                 f60_PM1_AMS:standard_name = "f60_PM1_AMS" ;
#                 f60_PM1_AMS:missing_value = -99999 ;
#                 f60_PM1_AMS:fill_value = -99999.0 ;
#                 f60_PM1_AMS:scale = 1 ;
#                 f60_PM1_AMS:llod_flag = -8888 ;
#                 f60_PM1_AMS:llod_value = "N/A" ;
#                 f60_PM1_AMS:ulod_flag = -7777 ;
#                 f60_PM1_AMS:ulod_value = "N/A" ;
#         double f82_PM1_AMS(POINTS);
#                 f82_PM1_AMS:units = "unitless" ;
#                 f82_PM1_AMS:standard_name = "f82_PM1_AMS" ;
#                 f82_PM1_AMS:missing_value = -99999 ;
#                 f82_PM1_AMS:fill_value = -99999.0 ;
#                 f82_PM1_AMS:scale = 1 ;
#                 f82_PM1_AMS:llod_flag = -8888 ;
#                 f82_PM1_AMS:llod_value = "N/A" ;
#                 f82_PM1_AMS:ulod_flag = -7777 ;
#                 f82_PM1_AMS:ulod_value = "N/A" ;
#         double f91_PM1_AMS(POINTS);
#                 f91_PM1_AMS:units = "unitless" ;
#                 f91_PM1_AMS:standard_name = "f91_PM1_AMS" ;
#                 f91_PM1_AMS:missing_value = -99999 ;
#                 f91_PM1_AMS:fill_value = -99999.0 ;
#                 f91_PM1_AMS:scale = 1 ;
#                 f91_PM1_AMS:llod_flag = -8888 ;
#                 f91_PM1_AMS:llod_value = "N/A" ;
#                 f91_PM1_AMS:ulod_flag = -7777 ;
#                 f91_PM1_AMS:ulod_value = "N/A" ;
#         double fC2H3O_PM1_AMS(POINTS);
#                 fC2H3O_PM1_AMS:units = "unitless" ;
#                 fC2H3O_PM1_AMS:standard_name = "fC2H3O_PM1_AMS" ;
#                 fC2H3O_PM1_AMS:missing_value = -99999 ;
#                 fC2H3O_PM1_AMS:fill_value = -99999.0 ;
#                 fC2H3O_PM1_AMS:scale = 1 ;
#                 fC2H3O_PM1_AMS:llod_flag = -8888 ;
#                 fC2H3O_PM1_AMS:llod_value = "N/A" ;
#                 fC2H3O_PM1_AMS:ulod_flag = -7777 ;
#                 fC2H3O_PM1_AMS:ulod_value = "N/A" ;
#         double fCO2_PM1_AMS(POINTS);
#                 fCO2_PM1_AMS:units = "unitless" ;
#                 fCO2_PM1_AMS:standard_name = "fCO2_PM1_AMS" ;
#                 fCO2_PM1_AMS:missing_value = -99999 ;
#                 fCO2_PM1_AMS:fill_value = -99999.0 ;
#                 fCO2_PM1_AMS:scale = 1 ;
#                 fCO2_PM1_AMS:llod_flag = -8888 ;
#                 fCO2_PM1_AMS:llod_value = "N/A" ;
#                 fCO2_PM1_AMS:ulod_flag = -7777 ;
#                 fCO2_PM1_AMS:ulod_value = "N/A" ;
#         double fC4H9_PM1_AMS(POINTS);
#                 fC4H9_PM1_AMS:units = "unitless" ;
#                 fC4H9_PM1_AMS:standard_name = "fC4H9_PM1_AMS" ;
#                 fC4H9_PM1_AMS:missing_value = -99999 ;
#                 fC4H9_PM1_AMS:fill_value = -99999.0 ;
#                 fC4H9_PM1_AMS:scale = 1 ;
#                 fC4H9_PM1_AMS:llod_flag = -8888 ;
#                 fC4H9_PM1_AMS:llod_value = "N/A" ;
#                 fC4H9_PM1_AMS:ulod_flag = -7777 ;
#                 fC4H9_PM1_AMS:ulod_value = "N/A" ;
#         double fC2H4O2_PM1_AMS(POINTS);
#                 fC2H4O2_PM1_AMS:units = "unitless" ;
#                 fC2H4O2_PM1_AMS:standard_name = "fC2H4O2_PM1_AMS" ;
#                 fC2H4O2_PM1_AMS:missing_value = -99999 ;
#                 fC2H4O2_PM1_AMS:fill_value = -99999.0 ;
#                 fC2H4O2_PM1_AMS:scale = 1 ;
#                 fC2H4O2_PM1_AMS:llod_flag = -8888 ;
#                 fC2H4O2_PM1_AMS:llod_value = "N/A" ;
#                 fC2H4O2_PM1_AMS:ulod_flag = -7777 ;
#                 fC2H4O2_PM1_AMS:ulod_value = "N/A" ;
#         double fC5H6O_PM1_AMS(POINTS);
#                 fC5H6O_PM1_AMS:units = "unitless" ;
#                 fC5H6O_PM1_AMS:standard_name = "fC5H6O_PM1_AMS" ;
#                 fC5H6O_PM1_AMS:missing_value = -99999 ;
#                 fC5H6O_PM1_AMS:fill_value = -99999.0 ;
#                 fC5H6O_PM1_AMS:scale = 1 ;
#                 fC5H6O_PM1_AMS:llod_flag = -8888 ;
#                 fC5H6O_PM1_AMS:llod_value = "N/A" ;
#                 fC5H6O_PM1_AMS:ulod_flag = -7777 ;
#                 fC5H6O_PM1_AMS:ulod_value = "N/A" ;
#         double fC7H7_PM1_AMS(POINTS);
#                 fC7H7_PM1_AMS:units = "unitless" ;
#                 fC7H7_PM1_AMS:standard_name = "fC7H7_PM1_AMS" ;
#                 fC7H7_PM1_AMS:missing_value = -99999 ;
#                 fC7H7_PM1_AMS:fill_value = -99999.0 ;
#                 fC7H7_PM1_AMS:scale = 1 ;
#                 fC7H7_PM1_AMS:llod_flag = -8888 ;
#                 fC7H7_PM1_AMS:llod_value = "N/A" ;
#                 fC7H7_PM1_AMS:ulod_flag = -7777 ;
#                 fC7H7_PM1_AMS:ulod_value = "N/A" ;
#         double OrgNitr_Fraction_PM1_AMS(POINTS);
#                 OrgNitr_Fraction_PM1_AMS:units = "unitless" ;
#                 OrgNitr_Fraction_PM1_AMS:standard_name = "OrgNitr_Fraction_PM1_AMS" ;
#                 OrgNitr_Fraction_PM1_AMS:missing_value = -99999 ;
#                 OrgNitr_Fraction_PM1_AMS:fill_value = -99999.0 ;
#                 OrgNitr_Fraction_PM1_AMS:scale = 1 ;
#                 OrgNitr_Fraction_PM1_AMS:llod_flag = -8888 ;
#                 OrgNitr_Fraction_PM1_AMS:llod_value = "N/A" ;
#                 OrgNitr_Fraction_PM1_AMS:ulod_flag = -7777 ;
#                 OrgNitr_Fraction_PM1_AMS:ulod_value = "N/A" ;
#         double CO2raw_AO2(POINTS);
#                 CO2raw_AO2:units = "ppm" ;
#                 CO2raw_AO2:standard_name = "CO2raw_AO2" ;
#                 CO2raw_AO2:missing_value = -99999 ;
#                 CO2raw_AO2:fill_value = -99999.0 ;
#                 CO2raw_AO2:scale = 1 ;
#                 CO2raw_AO2:llod_flag = -8888 ;
#                 CO2raw_AO2:llod_value = "N/A" ;
#                 CO2raw_AO2:ulod_flag = -7777 ;
#                 CO2raw_AO2:ulod_value = "N/A" ;
#         double O2N2raw_AO2(POINTS);
#                 O2N2raw_AO2:units = "per meg" ;
#                 O2N2raw_AO2:standard_name = "O2N2raw_AO2" ;
#                 O2N2raw_AO2:missing_value = -99999 ;
#                 O2N2raw_AO2:fill_value = -99999.0 ;
#                 O2N2raw_AO2:scale = 1 ;
#                 O2N2raw_AO2:llod_flag = -8888 ;
#                 O2N2raw_AO2:llod_value = "N/A" ;
#                 O2N2raw_AO2:ulod_flag = -7777 ;
#                 O2N2raw_AO2:ulod_value = "N/A" ;
#         double APOraw_AO2(POINTS);
#                 APOraw_AO2:units = "per meg" ;
#                 APOraw_AO2:standard_name = "APOraw_AO2" ;
#                 APOraw_AO2:missing_value = -99999 ;
#                 APOraw_AO2:fill_value = -99999.0 ;
#                 APOraw_AO2:scale = 1 ;
#                 APOraw_AO2:llod_flag = -8888 ;
#                 APOraw_AO2:llod_value = "N/A" ;
#                 APOraw_AO2:ulod_flag = -7777 ;
#                 APOraw_AO2:ulod_value = "N/A" ;
#         double CO2_AO2(POINTS);
#                 CO2_AO2:units = "ppm" ;
#                 CO2_AO2:standard_name = "CO2_AO2" ;
#                 CO2_AO2:missing_value = -99999 ;
#                 CO2_AO2:fill_value = -99999.0 ;
#                 CO2_AO2:scale = 1 ;
#                 CO2_AO2:llod_flag = -8888 ;
#                 CO2_AO2:llod_value = "N/A" ;
#                 CO2_AO2:ulod_flag = -7777 ;
#                 CO2_AO2:ulod_value = "N/A" ;
#         double O2N2_AO2(POINTS);
#                 O2N2_AO2:units = "per meg" ;
#                 O2N2_AO2:standard_name = "O2N2_AO2" ;
#                 O2N2_AO2:missing_value = -99999 ;
#                 O2N2_AO2:fill_value = -99999.0 ;
#                 O2N2_AO2:scale = 1 ;
#                 O2N2_AO2:llod_flag = -8888 ;
#                 O2N2_AO2:llod_value = "N/A" ;
#                 O2N2_AO2:ulod_flag = -7777 ;
#                 O2N2_AO2:ulod_value = "N/A" ;
#         double APO_AO2(POINTS);
#                 APO_AO2:units = "per meg" ;
#                 APO_AO2:standard_name = "APO_AO2" ;
#                 APO_AO2:missing_value = -99999 ;
#                 APO_AO2:fill_value = -99999.0 ;
#                 APO_AO2:scale = 1 ;
#                 APO_AO2:llod_flag = -8888 ;
#                 APO_AO2:llod_value = "N/A" ;
#                 APO_AO2:ulod_flag = -7777 ;
#                 APO_AO2:ulod_value = "N/A" ;
#         double OH_ATHOS(POINTS);
#                 OH_ATHOS:units = "pptv" ;
#                 OH_ATHOS:standard_name = "OH_ATHOS" ;
#                 OH_ATHOS:missing_value = -99999 ;
#                 OH_ATHOS:fill_value = -99999.0 ;
#                 OH_ATHOS:scale = 1 ;
#                 OH_ATHOS:llod_flag = -8888 ;
#                 OH_ATHOS:llod_value = "N/A" ;
#                 OH_ATHOS:ulod_flag = -7777 ;
#                 OH_ATHOS:ulod_value = "N/A" ;
#         double HO2_ATHOS(POINTS);
#                 HO2_ATHOS:units = "pptv" ;
#                 HO2_ATHOS:standard_name = "HO2_ATHOS" ;
#                 HO2_ATHOS:missing_value = -99999 ;
#                 HO2_ATHOS:fill_value = -99999.0 ;
#                 HO2_ATHOS:scale = 1 ;
#                 HO2_ATHOS:llod_flag = -8888 ;
#                 HO2_ATHOS:llod_value = "N/A" ;
#                 HO2_ATHOS:ulod_flag = -7777 ;
#                 HO2_ATHOS:ulod_value = "N/A" ;
#         double OHInterference_ATHOS(POINTS);
#                 OHInterference_ATHOS:units = "pptv" ;
#                 OHInterference_ATHOS:standard_name = "OHInterference_ATHOS" ;
#                 OHInterference_ATHOS:missing_value = -99999 ;
#                 OHInterference_ATHOS:fill_value = -99999.0 ;
#                 OHInterference_ATHOS:scale = 1 ;
#                 OHInterference_ATHOS:llod_flag = -8888 ;
#                 OHInterference_ATHOS:llod_value = "N/A" ;
#                 OHInterference_ATHOS:ulod_flag = -7777 ;
#                 OHInterference_ATHOS:ulod_value = "N/A" ;
#         double T_OHR(POINTS);
#                 T_OHR:units = "Kelvin" ;
#                 T_OHR:standard_name = "T_OHR" ;
#                 T_OHR:missing_value = -99999 ;
#                 T_OHR:fill_value = -99999.0 ;
#                 T_OHR:scale = 1 ;
#                 T_OHR:llod_flag = -8888 ;
#                 T_OHR:llod_value = "N/A" ;
#                 T_OHR:ulod_flag = -7777 ;
#                 T_OHR:ulod_value = "N/A" ;
#         double P_OHR(POINTS);
#                 P_OHR:units = "kPa" ;
#                 P_OHR:standard_name = "P_OHR" ;
#                 P_OHR:missing_value = -99999 ;
#                 P_OHR:fill_value = -99999.0 ;
#                 P_OHR:scale = 1 ;
#                 P_OHR:llod_flag = -8888 ;
#                 P_OHR:llod_value = "N/A" ;
#                 P_OHR:ulod_flag = -7777 ;
#                 P_OHR:ulod_value = "N/A" ;
#         double OHReactivity_OHR(POINTS);
#                 OHReactivity_OHR:units = "Hz" ;
#                 OHReactivity_OHR:standard_name = "OHReactivity_OHR" ;
#                 OHReactivity_OHR:missing_value = -99999 ;
#                 OHReactivity_OHR:fill_value = -99999.0 ;
#                 OHReactivity_OHR:scale = 1 ;
#                 OHReactivity_OHR:llod_flag = -8888 ;
#                 OHReactivity_OHR:llod_value = "N/A" ;
#                 OHReactivity_OHR:ulod_flag = -7777 ;
#                 OHReactivity_OHR:ulod_value = "N/A" ;
#         double jO3_O2_O1D_CAFS(POINTS);
#                 jO3_O2_O1D_CAFS:units = "/s" ;
#                 jO3_O2_O1D_CAFS:standard_name = "jO3_O2_O1D_CAFS" ;
#                 jO3_O2_O1D_CAFS:missing_value = -99999 ;
#                 jO3_O2_O1D_CAFS:fill_value = -99999.0 ;
#                 jO3_O2_O1D_CAFS:scale = 1 ;
#                 jO3_O2_O1D_CAFS:llod_flag = -8888 ;
#                 jO3_O2_O1D_CAFS:llod_value = "N/A" ;
#                 jO3_O2_O1D_CAFS:ulod_flag = -7777 ;
#                 jO3_O2_O1D_CAFS:ulod_value = "N/A" ;
#         double jNO2_NO_O3P_CAFS(POINTS);
#                 jNO2_NO_O3P_CAFS:units = "/s" ;
#                 jNO2_NO_O3P_CAFS:standard_name = "jNO2_NO_O3P_CAFS" ;
#                 jNO2_NO_O3P_CAFS:missing_value = -99999 ;
#                 jNO2_NO_O3P_CAFS:fill_value = -99999.0 ;
#                 jNO2_NO_O3P_CAFS:scale = 1 ;
#                 jNO2_NO_O3P_CAFS:llod_flag = -8888 ;
#                 jNO2_NO_O3P_CAFS:llod_value = "N/A" ;
#                 jNO2_NO_O3P_CAFS:ulod_flag = -7777 ;
#                 jNO2_NO_O3P_CAFS:ulod_value = "N/A" ;
#         double jH2O2_OH_OH_CAFS(POINTS);
#                 jH2O2_OH_OH_CAFS:units = "/s" ;
#                 jH2O2_OH_OH_CAFS:standard_name = "jH2O2_OH_OH_CAFS" ;
#                 jH2O2_OH_OH_CAFS:missing_value = -99999 ;
#                 jH2O2_OH_OH_CAFS:fill_value = -99999.0 ;
#                 jH2O2_OH_OH_CAFS:scale = 1 ;
#                 jH2O2_OH_OH_CAFS:llod_flag = -8888 ;
#                 jH2O2_OH_OH_CAFS:llod_value = "N/A" ;
#                 jH2O2_OH_OH_CAFS:ulod_flag = -7777 ;
#                 jH2O2_OH_OH_CAFS:ulod_value = "N/A" ;
#         double jNO3_NO_O2_CAFS(POINTS);
#                 jNO3_NO_O2_CAFS:units = "/s" ;
#                 jNO3_NO_O2_CAFS:standard_name = "jNO3_NO_O2_CAFS" ;
#                 jNO3_NO_O2_CAFS:missing_value = -99999 ;
#                 jNO3_NO_O2_CAFS:fill_value = -99999.0 ;
#                 jNO3_NO_O2_CAFS:scale = 1 ;
#                 jNO3_NO_O2_CAFS:llod_flag = -8888 ;
#                 jNO3_NO_O2_CAFS:llod_value = "N/A" ;
#                 jNO3_NO_O2_CAFS:ulod_flag = -7777 ;
#                 jNO3_NO_O2_CAFS:ulod_value = "N/A" ;
#         double jNO3_NO2_O3P_CAFS(POINTS);
#                 jNO3_NO2_O3P_CAFS:units = "/s" ;
#                 jNO3_NO2_O3P_CAFS:standard_name = "jNO3_NO2_O3P_CAFS" ;
#                 jNO3_NO2_O3P_CAFS:missing_value = -99999 ;
#                 jNO3_NO2_O3P_CAFS:fill_value = -99999.0 ;
#                 jNO3_NO2_O3P_CAFS:scale = 1 ;
#                 jNO3_NO2_O3P_CAFS:llod_flag = -8888 ;
#                 jNO3_NO2_O3P_CAFS:llod_value = "N/A" ;
#                 jNO3_NO2_O3P_CAFS:ulod_flag = -7777 ;
#                 jNO3_NO2_O3P_CAFS:ulod_value = "N/A" ;
#         double jN2O5_NO3_NO2_CAFS(POINTS);
#                 jN2O5_NO3_NO2_CAFS:units = "/s" ;
#                 jN2O5_NO3_NO2_CAFS:standard_name = "jN2O5_NO3_NO2_CAFS" ;
#                 jN2O5_NO3_NO2_CAFS:missing_value = -99999 ;
#                 jN2O5_NO3_NO2_CAFS:fill_value = -99999.0 ;
#                 jN2O5_NO3_NO2_CAFS:scale = 1 ;
#                 jN2O5_NO3_NO2_CAFS:llod_flag = -8888 ;
#                 jN2O5_NO3_NO2_CAFS:llod_value = "N/A" ;
#                 jN2O5_NO3_NO2_CAFS:ulod_flag = -7777 ;
#                 jN2O5_NO3_NO2_CAFS:ulod_value = "N/A" ;
#         double jHNO2_OH_NO_CAFS(POINTS);
#                 jHNO2_OH_NO_CAFS:units = "/s" ;
#                 jHNO2_OH_NO_CAFS:standard_name = "jHNO2_OH_NO_CAFS" ;
#                 jHNO2_OH_NO_CAFS:missing_value = -99999 ;
#                 jHNO2_OH_NO_CAFS:fill_value = -99999.0 ;
#                 jHNO2_OH_NO_CAFS:scale = 1 ;
#                 jHNO2_OH_NO_CAFS:llod_flag = -8888 ;
#                 jHNO2_OH_NO_CAFS:llod_value = "N/A" ;
#                 jHNO2_OH_NO_CAFS:ulod_flag = -7777 ;
#                 jHNO2_OH_NO_CAFS:ulod_value = "N/A" ;
#         double jHNO3_OH_NO2_CAFS(POINTS);
#                 jHNO3_OH_NO2_CAFS:units = "/s" ;
#                 jHNO3_OH_NO2_CAFS:standard_name = "jHNO3_OH_NO2_CAFS" ;
#                 jHNO3_OH_NO2_CAFS:missing_value = -99999 ;
#                 jHNO3_OH_NO2_CAFS:fill_value = -99999.0 ;
#                 jHNO3_OH_NO2_CAFS:scale = 1 ;
#                 jHNO3_OH_NO2_CAFS:llod_flag = -8888 ;
#                 jHNO3_OH_NO2_CAFS:llod_value = "N/A" ;
#                 jHNO3_OH_NO2_CAFS:ulod_flag = -7777 ;
#                 jHNO3_OH_NO2_CAFS:ulod_value = "N/A" ;
#         double jHNO4_HO2_NO2_UvVisOnly_CAFS(POINTS);
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:units = "/s" ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:standard_name = "jHNO4_HO2_NO2_UvVisOnly_CAFS" ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:missing_value = -99999 ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:fill_value = -99999.0 ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:scale = 1 ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:llod_flag = -8888 ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:llod_value = "N/A" ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:ulod_flag = -7777 ;
#                 jHNO4_HO2_NO2_UvVisOnly_CAFS:ulod_value = "N/A" ;
#         double jCH2O_H_HCO_CAFS(POINTS);
#                 jCH2O_H_HCO_CAFS:units = "/s" ;
#                 jCH2O_H_HCO_CAFS:standard_name = "jCH2O_H_HCO_CAFS" ;
#                 jCH2O_H_HCO_CAFS:missing_value = -99999 ;
#                 jCH2O_H_HCO_CAFS:fill_value = -99999.0 ;
#                 jCH2O_H_HCO_CAFS:scale = 1 ;
#                 jCH2O_H_HCO_CAFS:llod_flag = -8888 ;
#                 jCH2O_H_HCO_CAFS:llod_value = "N/A" ;
#                 jCH2O_H_HCO_CAFS:ulod_flag = -7777 ;
#                 jCH2O_H_HCO_CAFS:ulod_value = "N/A" ;
#         double jCH2O_H2_CO_CAFS(POINTS);
#                 jCH2O_H2_CO_CAFS:units = "/s" ;
#                 jCH2O_H2_CO_CAFS:standard_name = "jCH2O_H2_CO_CAFS" ;
#                 jCH2O_H2_CO_CAFS:missing_value = -99999 ;
#                 jCH2O_H2_CO_CAFS:fill_value = -99999.0 ;
#                 jCH2O_H2_CO_CAFS:scale = 1 ;
#                 jCH2O_H2_CO_CAFS:llod_flag = -8888 ;
#                 jCH2O_H2_CO_CAFS:llod_value = "N/A" ;
#                 jCH2O_H2_CO_CAFS:ulod_flag = -7777 ;
#                 jCH2O_H2_CO_CAFS:ulod_value = "N/A" ;
#         double jCH3CHO_CH3_HCO_CAFS(POINTS);
#                 jCH3CHO_CH3_HCO_CAFS:units = "/s" ;
#                 jCH3CHO_CH3_HCO_CAFS:standard_name = "jCH3CHO_CH3_HCO_CAFS" ;
#                 jCH3CHO_CH3_HCO_CAFS:missing_value = -99999 ;
#                 jCH3CHO_CH3_HCO_CAFS:fill_value = -99999.0 ;
#                 jCH3CHO_CH3_HCO_CAFS:scale = 1 ;
#                 jCH3CHO_CH3_HCO_CAFS:llod_flag = -8888 ;
#                 jCH3CHO_CH3_HCO_CAFS:llod_value = "N/A" ;
#                 jCH3CHO_CH3_HCO_CAFS:ulod_flag = -7777 ;
#                 jCH3CHO_CH3_HCO_CAFS:ulod_value = "N/A" ;
#         double jPropanal_CH2CH3_HCO_CAFS(POINTS);
#                 jPropanal_CH2CH3_HCO_CAFS:units = "/s" ;
#                 jPropanal_CH2CH3_HCO_CAFS:standard_name = "jPropanal_CH2CH3_HCO_CAFS" ;
#                 jPropanal_CH2CH3_HCO_CAFS:missing_value = -99999 ;
#                 jPropanal_CH2CH3_HCO_CAFS:fill_value = -99999.0 ;
#                 jPropanal_CH2CH3_HCO_CAFS:scale = 1 ;
#                 jPropanal_CH2CH3_HCO_CAFS:llod_flag = -8888 ;
#                 jPropanal_CH2CH3_HCO_CAFS:llod_value = "N/A" ;
#                 jPropanal_CH2CH3_HCO_CAFS:ulod_flag = -7777 ;
#                 jPropanal_CH2CH3_HCO_CAFS:ulod_value = "N/A" ;
#         double jCH3OOH_CH3O_OH_CAFS(POINTS);
#                 jCH3OOH_CH3O_OH_CAFS:units = "/s" ;
#                 jCH3OOH_CH3O_OH_CAFS:standard_name = "jCH3OOH_CH3O_OH_CAFS" ;
#                 jCH3OOH_CH3O_OH_CAFS:missing_value = -99999 ;
#                 jCH3OOH_CH3O_OH_CAFS:fill_value = -99999.0 ;
#                 jCH3OOH_CH3O_OH_CAFS:scale = 1 ;
#                 jCH3OOH_CH3O_OH_CAFS:llod_flag = -8888 ;
#                 jCH3OOH_CH3O_OH_CAFS:llod_value = "N/A" ;
#                 jCH3OOH_CH3O_OH_CAFS:ulod_flag = -7777 ;
#                 jCH3OOH_CH3O_OH_CAFS:ulod_value = "N/A" ;
#         double jMeONO2_CH3O_NO2_CAFS(POINTS);
#                 jMeONO2_CH3O_NO2_CAFS:units = "/s" ;
#                 jMeONO2_CH3O_NO2_CAFS:standard_name = "jMeONO2_CH3O_NO2_CAFS" ;
#                 jMeONO2_CH3O_NO2_CAFS:missing_value = -99999 ;
#                 jMeONO2_CH3O_NO2_CAFS:fill_value = -99999.0 ;
#                 jMeONO2_CH3O_NO2_CAFS:scale = 1 ;
#                 jMeONO2_CH3O_NO2_CAFS:llod_flag = -8888 ;
#                 jMeONO2_CH3O_NO2_CAFS:llod_value = "N/A" ;
#                 jMeONO2_CH3O_NO2_CAFS:ulod_flag = -7777 ;
#                 jMeONO2_CH3O_NO2_CAFS:ulod_value = "N/A" ;
#         double jEthONO2_CH3CH2O_NO2_CAFS(POINTS);
#                 jEthONO2_CH3CH2O_NO2_CAFS:units = "/s" ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:standard_name = "jEthONO2_CH3CH2O_NO2_CAFS" ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:missing_value = -99999 ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:fill_value = -99999.0 ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:scale = 1 ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:llod_flag = -8888 ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:llod_value = "N/A" ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:ulod_flag = -7777 ;
#                 jEthONO2_CH3CH2O_NO2_CAFS:ulod_value = "N/A" ;
#         double jPAN_CH3COO2_NO2_CAFS(POINTS);
#                 jPAN_CH3COO2_NO2_CAFS:units = "/s" ;
#                 jPAN_CH3COO2_NO2_CAFS:standard_name = "jPAN_CH3COO2_NO2_CAFS" ;
#                 jPAN_CH3COO2_NO2_CAFS:missing_value = -99999 ;
#                 jPAN_CH3COO2_NO2_CAFS:fill_value = -99999.0 ;
#                 jPAN_CH3COO2_NO2_CAFS:scale = 1 ;
#                 jPAN_CH3COO2_NO2_CAFS:llod_flag = -8888 ;
#                 jPAN_CH3COO2_NO2_CAFS:llod_value = "N/A" ;
#                 jPAN_CH3COO2_NO2_CAFS:ulod_flag = -7777 ;
#                 jPAN_CH3COO2_NO2_CAFS:ulod_value = "N/A" ;
#         double jPAN_CH3COO_NO3_CAFS(POINTS);
#                 jPAN_CH3COO_NO3_CAFS:units = "/s" ;
#                 jPAN_CH3COO_NO3_CAFS:standard_name = "jPAN_CH3COO_NO3_CAFS" ;
#                 jPAN_CH3COO_NO3_CAFS:missing_value = -99999 ;
#                 jPAN_CH3COO_NO3_CAFS:fill_value = -99999.0 ;
#                 jPAN_CH3COO_NO3_CAFS:scale = 1 ;
#                 jPAN_CH3COO_NO3_CAFS:llod_flag = -8888 ;
#                 jPAN_CH3COO_NO3_CAFS:llod_value = "N/A" ;
#                 jPAN_CH3COO_NO3_CAFS:ulod_flag = -7777 ;
#                 jPAN_CH3COO_NO3_CAFS:ulod_value = "N/A" ;
#         double jMAC_NoProductsSpecified_CAFS(POINTS);
#                 jMAC_NoProductsSpecified_CAFS:units = "/s" ;
#                 jMAC_NoProductsSpecified_CAFS:standard_name = "jMAC_NoProductsSpecified_CAFS" ;
#                 jMAC_NoProductsSpecified_CAFS:missing_value = -99999 ;
#                 jMAC_NoProductsSpecified_CAFS:fill_value = -99999.0 ;
#                 jMAC_NoProductsSpecified_CAFS:scale = 1 ;
#                 jMAC_NoProductsSpecified_CAFS:llod_flag = -8888 ;
#                 jMAC_NoProductsSpecified_CAFS:llod_value = "N/A" ;
#                 jMAC_NoProductsSpecified_CAFS:ulod_flag = -7777 ;
#                 jMAC_NoProductsSpecified_CAFS:ulod_value = "N/A" ;
#         double jMVK_NoProductsSpecified_CAFS(POINTS);
#                 jMVK_NoProductsSpecified_CAFS:units = "/s" ;
#                 jMVK_NoProductsSpecified_CAFS:standard_name = "jMVK_NoProductsSpecified_CAFS" ;
#                 jMVK_NoProductsSpecified_CAFS:missing_value = -99999 ;
#                 jMVK_NoProductsSpecified_CAFS:fill_value = -99999.0 ;
#                 jMVK_NoProductsSpecified_CAFS:scale = 1 ;
#                 jMVK_NoProductsSpecified_CAFS:llod_flag = -8888 ;
#                 jMVK_NoProductsSpecified_CAFS:llod_value = "N/A" ;
#                 jMVK_NoProductsSpecified_CAFS:ulod_flag = -7777 ;
#                 jMVK_NoProductsSpecified_CAFS:ulod_value = "N/A" ;
#         double jAcetone_CH3CO_CH3_CAFS(POINTS);
#                 jAcetone_CH3CO_CH3_CAFS:units = "/s" ;
#                 jAcetone_CH3CO_CH3_CAFS:standard_name = "jAcetone_CH3CO_CH3_CAFS" ;
# ...
#                 Tricyclene_TOGA:units = "ppt" ;
#                 Tricyclene_TOGA:standard_name = "Tricyclene_TOGA" ;
#                 Tricyclene_TOGA:missing_value = -99999 ;
#                 Tricyclene_TOGA:fill_value = -99999.0 ;
#                 Tricyclene_TOGA:scale = 1 ;
#                 Tricyclene_TOGA:llod_flag = -8888 ;
#                 Tricyclene_TOGA:llod_value = "N/A" ;
#                 Tricyclene_TOGA:ulod_flag = -7777 ;
#                 Tricyclene_TOGA:ulod_value = "N/A" ;
#         double Camphene_TOGA(POINTS);
#                 Camphene_TOGA:units = "ppt" ;
#                 Camphene_TOGA:standard_name = "Camphene_TOGA" ;
#                 Camphene_TOGA:missing_value = -99999 ;
#                 Camphene_TOGA:fill_value = -99999.0 ;
#                 Camphene_TOGA:scale = 1 ;
#                 Camphene_TOGA:llod_flag = -8888 ;
#                 Camphene_TOGA:llod_value = "N/A" ;
#                 Camphene_TOGA:ulod_flag = -7777 ;
#                 Camphene_TOGA:ulod_value = "N/A" ;
#         double bPineneMyrcene_TOGA(POINTS);
#                 bPineneMyrcene_TOGA:units = "ppt" ;
#                 bPineneMyrcene_TOGA:standard_name = "bPineneMyrcene_TOGA" ;
#                 bPineneMyrcene_TOGA:missing_value = -99999 ;
#                 bPineneMyrcene_TOGA:fill_value = -99999.0 ;
#                 bPineneMyrcene_TOGA:scale = 1 ;
#                 bPineneMyrcene_TOGA:llod_flag = -8888 ;
#                 bPineneMyrcene_TOGA:llod_value = "N/A" ;
#                 bPineneMyrcene_TOGA:ulod_flag = -7777 ;
#                 bPineneMyrcene_TOGA:ulod_value = "N/A" ;
#         double LimoneneD3Carene_TOGA(POINTS);
#                 LimoneneD3Carene_TOGA:units = "ppt" ;
#                 LimoneneD3Carene_TOGA:standard_name = "LimoneneD3Carene_TOGA" ;
#                 LimoneneD3Carene_TOGA:missing_value = -99999 ;
#                 LimoneneD3Carene_TOGA:fill_value = -99999.0 ;
#                 LimoneneD3Carene_TOGA:scale = 1 ;
#                 LimoneneD3Carene_TOGA:llod_flag = -8888 ;
#                 LimoneneD3Carene_TOGA:llod_value = "N/A" ;
#                 LimoneneD3Carene_TOGA:ulod_flag = -7777 ;
#                 LimoneneD3Carene_TOGA:ulod_value = "N/A" ;
#         double CH2O_TOGA(POINTS);
#                 CH2O_TOGA:units = "ppt" ;
#                 CH2O_TOGA:standard_name = "CH2O_TOGA" ;
#                 CH2O_TOGA:missing_value = -99999 ;
#                 CH2O_TOGA:fill_value = -99999.0 ;
#                 CH2O_TOGA:scale = 1 ;
#                 CH2O_TOGA:llod_flag = -8888 ;
#                 CH2O_TOGA:llod_value = "N/A" ;
#                 CH2O_TOGA:ulod_flag = -7777 ;
#                 CH2O_TOGA:ulod_value = "N/A" ;
#         double CH3CHO_TOGA(POINTS);
#                 CH3CHO_TOGA:units = "ppt" ;
#                 CH3CHO_TOGA:standard_name = "CH3CHO_TOGA" ;
#                 CH3CHO_TOGA:missing_value = -99999 ;
#                 CH3CHO_TOGA:fill_value = -99999.0 ;
#                 CH3CHO_TOGA:scale = 1 ;
#                 CH3CHO_TOGA:llod_flag = -8888 ;
#                 CH3CHO_TOGA:llod_value = "N/A" ;
#                 CH3CHO_TOGA:ulod_flag = -7777 ;
#                 CH3CHO_TOGA:ulod_value = "N/A" ;
#         double Propanal_TOGA(POINTS);
#                 Propanal_TOGA:units = "ppt" ;
#                 Propanal_TOGA:standard_name = "Propanal_TOGA" ;
#                 Propanal_TOGA:missing_value = -99999 ;
#                 Propanal_TOGA:fill_value = -99999.0 ;
#                 Propanal_TOGA:scale = 1 ;
#                 Propanal_TOGA:llod_flag = -8888 ;
#                 Propanal_TOGA:llod_value = "N/A" ;
#                 Propanal_TOGA:ulod_flag = -7777 ;
#                 Propanal_TOGA:ulod_value = "N/A" ;
#         double Butanal_TOGA(POINTS);
#                 Butanal_TOGA:units = "ppt" ;
#                 Butanal_TOGA:standard_name = "Butanal_TOGA" ;
#                 Butanal_TOGA:missing_value = -99999 ;
#                 Butanal_TOGA:fill_value = -99999.0 ;
#                 Butanal_TOGA:scale = 1 ;
#                 Butanal_TOGA:llod_flag = -8888 ;
#                 Butanal_TOGA:llod_value = "N/A" ;
#                 Butanal_TOGA:ulod_flag = -7777 ;
#                 Butanal_TOGA:ulod_value = "N/A" ;
#         double Acrolein_TOGA(POINTS);
#                 Acrolein_TOGA:units = "ppt" ;
#                 Acrolein_TOGA:standard_name = "Acrolein_TOGA" ;
#                 Acrolein_TOGA:missing_value = -99999 ;
#                 Acrolein_TOGA:fill_value = -99999.0 ;
#                 Acrolein_TOGA:scale = 1 ;
#                 Acrolein_TOGA:llod_flag = -8888 ;
#                 Acrolein_TOGA:llod_value = "N/A" ;
#                 Acrolein_TOGA:ulod_flag = -7777 ;
#                 Acrolein_TOGA:ulod_value = "N/A" ;
#         double MAC_TOGA(POINTS);
#                 MAC_TOGA:units = "ppt" ;
#                 MAC_TOGA:standard_name = "MAC_TOGA" ;
#                 MAC_TOGA:missing_value = -99999 ;
#                 MAC_TOGA:fill_value = -99999.0 ;
#                 MAC_TOGA:scale = 1 ;
#                 MAC_TOGA:llod_flag = -8888 ;
#                 MAC_TOGA:llod_value = "N/A" ;
#                 MAC_TOGA:ulod_flag = -7777 ;
#                 MAC_TOGA:ulod_value = "N/A" ;
#         double Acetone_TOGA(POINTS);
#                 Acetone_TOGA:units = "ppt" ;
#                 Acetone_TOGA:standard_name = "Acetone_TOGA" ;
#                 Acetone_TOGA:missing_value = -99999 ;
#                 Acetone_TOGA:fill_value = -99999.0 ;
#                 Acetone_TOGA:scale = 1 ;
#                 Acetone_TOGA:llod_flag = -8888 ;
#                 Acetone_TOGA:llod_value = "N/A" ;
#                 Acetone_TOGA:ulod_flag = -7777 ;
#                 Acetone_TOGA:ulod_value = "N/A" ;
#         double MEK_TOGA(POINTS);
#                 MEK_TOGA:units = "ppt" ;
#                 MEK_TOGA:standard_name = "MEK_TOGA" ;
#                 MEK_TOGA:missing_value = -99999 ;
#                 MEK_TOGA:fill_value = -99999.0 ;
#                 MEK_TOGA:scale = 1 ;
#                 MEK_TOGA:llod_flag = -8888 ;
#                 MEK_TOGA:llod_value = "N/A" ;
#                 MEK_TOGA:ulod_flag = -7777 ;
#                 MEK_TOGA:ulod_value = "N/A" ;
#         double MVK_TOGA(POINTS);
#                 MVK_TOGA:units = "ppt" ;
#                 MVK_TOGA:standard_name = "MVK_TOGA" ;
#                 MVK_TOGA:missing_value = -99999 ;
#                 MVK_TOGA:fill_value = -99999.0 ;
#                 MVK_TOGA:scale = 1 ;
#                 MVK_TOGA:llod_flag = -8888 ;
#                 MVK_TOGA:llod_value = "N/A" ;
#                 MVK_TOGA:ulod_flag = -7777 ;
#                 MVK_TOGA:ulod_value = "N/A" ;
#         double CH3OH_TOGA(POINTS);
#                 CH3OH_TOGA:units = "ppt" ;
#                 CH3OH_TOGA:standard_name = "CH3OH_TOGA" ;
#                 CH3OH_TOGA:missing_value = -99999 ;
#                 CH3OH_TOGA:fill_value = -99999.0 ;
#                 CH3OH_TOGA:scale = 1 ;
#                 CH3OH_TOGA:llod_flag = -8888 ;
#                 CH3OH_TOGA:llod_value = "N/A" ;
#                 CH3OH_TOGA:ulod_flag = -7777 ;
#                 CH3OH_TOGA:ulod_value = "N/A" ;
#         double C2H5OH_TOGA(POINTS);
#                 C2H5OH_TOGA:units = "ppt" ;
#                 C2H5OH_TOGA:standard_name = "C2H5OH_TOGA" ;
#                 C2H5OH_TOGA:missing_value = -99999 ;
#                 C2H5OH_TOGA:fill_value = -99999.0 ;
#                 C2H5OH_TOGA:scale = 1 ;
#                 C2H5OH_TOGA:llod_flag = -8888 ;
#                 C2H5OH_TOGA:llod_value = "N/A" ;
#                 C2H5OH_TOGA:ulod_flag = -7777 ;
#                 C2H5OH_TOGA:ulod_value = "N/A" ;
#         double MTBE_TOGA(POINTS);
#                 MTBE_TOGA:units = "ppt" ;
#                 MTBE_TOGA:standard_name = "MTBE_TOGA" ;
#                 MTBE_TOGA:missing_value = -99999 ;
#                 MTBE_TOGA:fill_value = -99999.0 ;
#                 MTBE_TOGA:scale = 1 ;
#                 MTBE_TOGA:llod_flag = -8888 ;
#                 MTBE_TOGA:llod_value = "N/A" ;
#                 MTBE_TOGA:ulod_flag = -7777 ;
#                 MTBE_TOGA:ulod_value = "N/A" ;
#         double DMS_TOGA(POINTS);
#                 DMS_TOGA:units = "ppt" ;
#                 DMS_TOGA:standard_name = "DMS_TOGA" ;
#                 DMS_TOGA:missing_value = -99999 ;
#                 DMS_TOGA:fill_value = -99999.0 ;
#                 DMS_TOGA:scale = 1 ;
#                 DMS_TOGA:llod_flag = -8888 ;
#                 DMS_TOGA:llod_value = "N/A" ;
#                 DMS_TOGA:ulod_flag = -7777 ;
#                 DMS_TOGA:ulod_value = "N/A" ;
#         double HCN_TOGA(POINTS);
#                 HCN_TOGA:units = "ppt" ;
#                 HCN_TOGA:standard_name = "HCN_TOGA" ;
#                 HCN_TOGA:missing_value = -99999 ;
#                 HCN_TOGA:fill_value = -99999.0 ;
#                 HCN_TOGA:scale = 1 ;
#                 HCN_TOGA:llod_flag = -8888 ;
#                 HCN_TOGA:llod_value = "N/A" ;
#                 HCN_TOGA:ulod_flag = -7777 ;
#                 HCN_TOGA:ulod_value = "N/A" ;
#         double CH3CN_TOGA(POINTS);
#                 CH3CN_TOGA:units = "ppt" ;
#                 CH3CN_TOGA:standard_name = "CH3CN_TOGA" ;
#                 CH3CN_TOGA:missing_value = -99999 ;
#                 CH3CN_TOGA:fill_value = -99999.0 ;
#                 CH3CN_TOGA:scale = 1 ;
#                 CH3CN_TOGA:llod_flag = -8888 ;
#                 CH3CN_TOGA:llod_value = "N/A" ;
#                 CH3CN_TOGA:ulod_flag = -7777 ;
#                 CH3CN_TOGA:ulod_value = "N/A" ;
#         double EthONO2_TOGA(POINTS);
#                 EthONO2_TOGA:units = "ppt" ;
#                 EthONO2_TOGA:standard_name = "EthONO2_TOGA" ;
#                 EthONO2_TOGA:missing_value = -99999 ;
#                 EthONO2_TOGA:fill_value = -99999.0 ;
#                 EthONO2_TOGA:scale = 1 ;
#                 EthONO2_TOGA:llod_flag = -8888 ;
#                 EthONO2_TOGA:llod_value = "N/A" ;
#                 EthONO2_TOGA:ulod_flag = -7777 ;
#                 EthONO2_TOGA:ulod_value = "N/A" ;
#         double iPropONO2_TOGA(POINTS);
#                 iPropONO2_TOGA:units = "ppt" ;
#                 iPropONO2_TOGA:standard_name = "iPropONO2_TOGA" ;
#                 iPropONO2_TOGA:missing_value = -99999 ;
#                 iPropONO2_TOGA:fill_value = -99999.0 ;
#                 iPropONO2_TOGA:scale = 1 ;
#                 iPropONO2_TOGA:llod_flag = -8888 ;
#                 iPropONO2_TOGA:llod_value = "N/A" ;
#                 iPropONO2_TOGA:ulod_flag = -7777 ;
#                 iPropONO2_TOGA:ulod_value = "N/A" ;
#
#
# // global properties:
#                 :fmt = "1001" ;
#                 :n_header_lines = 695 ;
#                 :PI_NAME = "Wofsy,S" ;
#                 :ORGANIZATION_NAME = "Harvard_University" ;
#                 :SOURCE_DESCRIPTION = "merge of 1s ATom DC-8 data with TOGA flask samples" ;
#                 :MISSION_NAME = "ATom" ;
#                 :VOLUME_INFO = "1, 1" ;
#                 :SDATE = "2017, 01, 26" ;
#                 :WDATE = "2020, 04, 11" ;
#                 :TIME_INTERVAL = "0" ;
#                 :INDEPENDENT_VARIABLE_DEFINITION = "UTC_Start, s" ;
#                 :INDEPENDENT_VARIABLE = "UTC_Start" ;
#                 :INDEPENDENT_VARIABLE_UNITS = "s" ;
#                 :SPECIAL_COMMENTS = "File,YYYY,MM,DD,yyyy,mm,dd,R#MMS-1HZ_DC8_20170126_R1.ict,2017,1,26,2017,9,29,1AMS_DC8_20170126_R1.ict,2017,1,26,2017,12,4,1AO2_DC8_20170126_R3_a.ict,2017,1,26,2019,6,3,3ATHOS-HOx_DC8_20170126_R5.ict,2017,1,26,2019,5,24,5ATHOS-OHI_DC8_20170126_R2.ict,2017,1,26,2019,5,24,2ATHOS-OHR_DC8_20170126_R2.ict,2017,1,26,2019,5,24,2CAFS-JV_DC8_20170126_R3.ict,2017,1,26,2019,5,17,3CIT-H2O2_DC8_20170126_R1.ict,2017,1,26,2018,1,15,1CIT-HCN_DC8_20170126_R1.ict,2017,1,26,2018,1,15,1CIT-HNO3_DC8_20170126_R1.ict,2017,1,26,2018,1,15,1CIT-MHP_DC8_20170126_R2.ict,2017,1,26,2018,3,9,2CIT-PAA_DC8_20170126_R1.ict,2017,1,26,2018,1,15,1CIT-PNA_DC8_20170126_R1.ict,2017,1,26,2018,1,15,1CIT-SO2_DC8_20170126_R2.ict,2017,1,26,2019,10,17,2Cloudindicator_DC8_20170126_R4.ict,2017,1,26,2020,4,9,4DLH-H2O_DC8_20170126_R2.ict,2017,1,26,2019,2,5,2GCECD_DC8_20170126_R1.ict,2017,1,26,2017,7,23,1GEOS5_DC8_20170126_R3.ict,2017,1,26,2019,5,16,3GMI_DC8_20170126_R2.ict,2017,1,26,2018,10,16,2GTCIMSPANS_DC8_20170126_R1.ict,2017,1,26,2018,9,29,1Hskping_DC8_20170126_R1.ict,2017,1,26,2018,7,31,1ISAF-H2CO_DC8_20170126_R3.ict,2017,1,26,2019,6,25,3Influences_DC8_20170126_R2.ict,2017,1,26,2018,8,27,2LASaerosol_DC8_20170126_R2.ict,2017,1,26,2018,10,9,2NAerosol_DC8_20170126_R3.ict,2017,1,26,2019,1,16,3NCoarseAerosol_DC8_20170126_R4.ict,2017,1,26,2018,12,3,4NOAA-Picarro-CO2-CH4-CO_DC8_20170126_R3.ict,2017,1,26,2017,7,1,3NOyO3-NO2PSS_DC8_20170126_R0.ict,2017,1,26,2018,3,13,0NOyO3-NO2_DC8_20170126_R1.ict,2017,1,26,2017,11,20,1NOyO3-NO_DC8_20170126_R1.ict,2017,1,26,2017,11,20,1NOyO3-NOxPSS_DC8_20170126_R0.ict,2017,1,26,2018,3,13,0NOyO3-NOy_DC8_20170126_R1.ict,2017,1,26,2017,11,20,1NOyO3-O3_DC8_20170126_R1.ict,2017,1,26,2017,11,20,1PALMS-Chem-Mass_DC8_20170126_R1.ict,2017,1,26,2019,11,14,1PALMS-PartType-Mass_DC8_20170126_R1.ict,2017,1,26,2019,11,14,1PALMS_DC8_20170126_R2.ict,2017,1,26,2019,11,14,2QCLS-CH4-CO-N2O_DC8_20170126_R4.ict,2017,1,26,2020,3,31,4QCLS-CO2_DC8_20170126_R3.ict,2017,1,26,2019,6,6,3SAGA-Abs_DC8_20170126_R0.ict,2017,1,26,2017,12,1,0SDAerosol_DC8_20170126_R1.ict,2017,1,26,2019,2,27,1SP2-BC_DC8_20170126_R2.ict,2017,1,26,2018,12,3,2UCATS-GC_DC8_20170126_R1.ict,2017,1,26,2017,12,7,1UCATS-H2O_DC8_20170126_R0.ict,2017,1,26,2018,7,6,0UCATS-O3_DC8_20170126_R2.ict,2017,1,26,2017,5,22,2CO_QCLS gap filled with smoothed CO_NOAA (Level3 data product)" ;
#                 :Flag = "CO2_NOAA=0, CO2_QCLS=1Profile Number (>0) ; high level leg = 0 ; low level leg = -1Distance in km along the flight trackTOGA_DC8_20170126_R4.ict,2017,1,26,2018,12,4,4" ;
#                 :PI_CONTACT_INFO = "Steven C. Wofsy, +1 617 495 4566; 29 Oxford St., Cambridge, MA 02138 USA; steven_wofsy@harvard.edu" ;
#                 :PLATFORM = "NASA DC-8 aircraft" ;
#                 :LOCATION = "DC-8 location data available at http://espoarchive.nasa.gov/archive/fileinfo/MMS-FlightPath_DC8_YYYYMMDD.ict" ;
#                 :ASSOCIATED_DATA = "see http://espoarchive.nasa.gov/archive/browse/atom" ;
#                 :INSTRUMENT_INFO = "measurement sources from ESPO archive data for sensors as indicated" ;
#                 :DATA_INFO = "Each column is data from a single sensor, named as Species_ATom file prefix, possibly shortened. Example: CO2_NOAA_Picarro is the CO2 column from the file NOAA-Picarro-CO2-CH4-CO_DC8_YYYYMMDD_R#.ict, where R# is the latest revision number valid on the date of the merge." ;
#                 :UNCERTAINTY = "See parent data files; the 10s means given here would usually have smaller confidence intervals than 1 Hz data by factor 2-3." ;
#                 :ULOD_FLAG = "-7777" ;
#                 :ULOD_VALUE = "N/A" ;
#                 :LLOD_FLAG = "-8888" ;
#                 :LLOD_VALUE = "N/A" ;
#                 :DM_CONTACT_INFO = "Steven C. Wofsy (see above)" ;
#                 :PROJECT_INFO = "Atmospheric Tomography Mission, Phase 1, August 2016" ;
#                 :STIPULATIONS_ON_USE = "ATom data policy and any additional stipulations in the underlying data sets. Users should check the archive for revisions of underlying data sets that occurred after this merge. Only current revisions of data can be used in publications. Obsolete data cannot be used, hence users of this merge may need to update individual data sets. Publications using this merged product must specify that this merge was used." ;
#                 :OTHER_COMMENTS = "N/A" ;
#                 :REVISION = "R20" ;
#                 :R1 = "updated" ;
#                 :R2 = "updated" ;
#                 :R3 = "updated" ;
#                 :R4 = "updated" ;
#                 :R5 = "updated" ;
#                 :R6 = "updated" ;
#                 :R7 = "updated" ;
#                 :R8 = "updated" ;
#                 :R9 = "updated" ;
#                 :R10 = "updated" ;
#                 :R11 = "updated" ;
#                 :R12 = "updated" ;
#                 :R13 = "updated" ;
#                 :R14 = "updated" ;
#                 :R15 = "updated" ;
#                 :R16 = "updated" ;
#                 :R17 = "updated" ;
#                 :R18 = "updated" ;
#                 :R19 = "updated" ;
#                 :R20 = "updated" ;
#                 :TFLAG = "UTC_Start" ;
# }

# %%
lon = infile.variables['G_LONG'][...]
lat = infile.variables['G_LAT'][...]
alt = infile.variables['G_ALT'][...]

# %%
figure = plt.figure(figsize=(8,6))
ax = figure.add_subplot(1,1,1, projection=ccrs.PlateCarree())
ax.coastlines()
ax.set_extent([-180, 180, -80, 80])
ax.scatter(lon,lat)

# %%
inpath = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170201_R18.ict'
infile = pnc.pncopen(inpath, format = 'ffi1001')

lon2 = infile.variables['G_LONG'][...]
lat2 = infile.variables['G_LAT'][...]
alt2 = infile.variables['G_ALT'][...]

inpath3 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170203_R18.ict'
infile = pnc.pncopen(inpath3, format = 'ffi1001')

lon3 = infile.variables['G_LONG'][...]
lat3 = infile.variables['G_LAT'][...]
alt3 = infile.variables['G_ALT'][...]

inpath4 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170205_R18.ict'
infile = pnc.pncopen(inpath4, format = 'ffi1001')

lon4 = infile.variables['G_LONG'][...]
lat4 = infile.variables['G_LAT'][...]
alt4 = infile.variables['G_ALT'][...]

inpath5 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170210_R18.ict'
infile = pnc.pncopen(inpath5, format = 'ffi1001')

lon5 = infile.variables['G_LONG'][...]
lat5 = infile.variables['G_LAT'][...]
alt5 = infile.variables['G_ALT'][...]

inpath6 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170213_R18.ict'
infile = pnc.pncopen(inpath6, format = 'ffi1001')

lon6 = infile.variables['G_LONG'][...]
lat6 = infile.variables['G_LAT'][...]
alt6 = infile.variables['G_ALT'][...]


inpath7 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170215_R18.ict'
infile = pnc.pncopen(inpath7, format = 'ffi1001')

lon7 = infile.variables['G_LONG'][...]
lat7 = infile.variables['G_LAT'][...]
alt7 = infile.variables['G_ALT'][...]

inpath8 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170218_R18.ict'
infile = pnc.pncopen(inpath8, format = 'ffi1001')

lon8 = infile.variables['G_LONG'][...]
lat8 = infile.variables['G_LAT'][...]
alt8 = infile.variables['G_ALT'][...]

inpath9 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170219_R18.ict'
infile = pnc.pncopen(inpath9, format = 'ffi1001')

lon9 = infile.variables['G_LONG'][...]
lat9 = infile.variables['G_LAT'][...]
alt9 = infile.variables['G_ALT'][...]


inpath10 = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170221_R18.ict'
infile = pnc.pncopen(inpath10, format = 'ffi1001')

lon10 = infile.variables['G_LONG'][...]
lat10 = infile.variables['G_LAT'][...]
alt10 = infile.variables['G_ALT'][...]

# %%
import PseudoNetCDF as pnc
import cartopy.crs as ccrs
from cartopy import config
import matplotlib.pyplot as plt

inpath = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170129_R18.ict'

infile = pnc.pncopen(inpath, format = 'ffi1001')

lon1 = infile.variables['G_LONG'][...]
lat1 = infile.variables['G_LAT'][...]
alt1 = infile.variables['G_ALT'][...]

figure = plt.figure(figsize=(12,10))
ax = figure.add_subplot(1,1,1, projection=ccrs.PlateCarree())
#ax = figure.add_subplot(1,1,1, projection=ccrs.PlateCarree(central_longitude=-200))
#ax = figure.add_subplot(1,1,1, projection=ccrs.Mollweide(central_longitude=-150, globe=None, false_easting=None, false_northing=None))
ax.coastlines()
#ax.set_extent([140, -180, -80, 80])
ax.scatter(lon1,lat1, c=alt1, cmap='plasma')
im = ax.scatter(lon,lat, c=alt, cmap='plasma')
ax.scatter(lon2,lat2, c=alt2, cmap='plasma')
ax.scatter(lon3,lat3, c=alt3, cmap='plasma')
ax.scatter(lon4,lat4, c=alt4, cmap='plasma')
ax.scatter(lon5,lat5, c=alt5, cmap='plasma')
ax.scatter(lon6,lat6, c=alt6, cmap='plasma')
ax.scatter(lon7,lat7, c=alt7, cmap='plasma')
ax.scatter(lon8,lat8, c=alt8, cmap='plasma')
ax.scatter(lon9,lat9, c=alt9, cmap='plasma')
ax.scatter(lon10,lat10, c=alt10, cmap='plasma')
figure.colorbar(im, ax=ax, shrink=0.5, label='Meters')

# %%
import PseudoNetCDF as pnc
import cartopy.crs as ccrs
from cartopy import config
import matplotlib.pyplot as plt

inpath = '/Users/mshogrin/Data/ATS621/MER-TOGA_DC8_20170129_R18.ict'

infile = pnc.pncopen(inpath, format = 'ffi1001')

lon1 = infile.variables['G_LONG'][...]
lat1 = infile.variables['G_LAT'][...]
alt1 = infile.variables['G_ALT'][...]

figure = plt.figure(figsize=(12,10))
#ax = figure.add_subplot(1,1,1, projection=ccrs.PlateCarree())
ax = figure.add_subplot(1,1,1, projection=ccrs.PlateCarree(central_longitude=-30))
#ax = figure.add_subplot(1,1,1, projection=ccrs.Mollweide(central_longitude=-150, globe=None, false_easting=None, false_northing=None))
ax.coastlines()
#ax.set_extent([140, -180, -80, 80])
ax.scatter(30+lon1,lat1, c=alt1, cmap='plasma')
im = ax.scatter(30+lon,lat, c=alt, cmap='plasma')
ax.scatter(30+lon2,lat2, c=alt2, cmap='plasma')
ax.scatter(30+lon3,lat3, c=alt3, cmap='plasma')
ax.scatter(30+lon4,lat4, c=alt4, cmap='plasma')
ax.scatter(30+lon5,lat5, c=alt5, cmap='plasma')
ax.scatter(30+lon6,lat6, c=alt6, cmap='plasma')
ax.scatter(30+lon7,lat7, c=alt7, cmap='plasma')
ax.scatter(30+lon8,lat8, c=alt8, cmap='plasma')
ax.scatter(30+lon9,lat9, c=alt9, cmap='plasma')
ax.scatter(30+lon10,lat10, c=alt10, cmap='plasma')
plt.title('ATom-2 Flight', fontsize=14)
figure.colorbar(im, ax=ax, shrink=0.5, label='Meters')
